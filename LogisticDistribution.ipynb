# %%
from sympy.plotting import plot

# %%
from sympy import exp, tanh

# %%
from sympy.abc import x

# %%
from sympy.stats import Logistic, density, cdf, Normal

# %%
from scipy.stats import logistic, norm

# %%
logistic.pdf(0)
# Out:
# 0.25

# %%
logistic.cdf(0)
# Out:
# 0.5

# %%
norm.pdf(0)
# Out:
# 0.3989422804014327

# %%
norm.cdf(0)
# Out:
# 0.5

# %%
plot(1/(1+exp(-x)))

# %%
plot((exp(x)-exp(-x))/(exp(-x)+exp(x)))

# %%
plot(tanh(x))

# %%
density(Logistic(x, 0, 1))
# Out:
# LogisticDistribution(0, 1)

# %%
cdf(Logistic(x, 0, 1))
# Out:
# Lambda(_z, 1/(1 + exp(-_z)))

# %%
plot(density(Logistic(x, 0, 1)))

# %%
plot(cdf(Logistic(x, 0, 1)))

# %%
density(Normal(x, 0, 1))
# Out:
# NormalDistribution(0, 1)

# %%
cdf(Normal(x, 0, 1))
# Out:
# Lambda(_z, erf(sqrt(2)*_z/2)/2 + 1/2)

# %%
plot(density(Normal(x, 0, 1)))

# %%
plot(cdf(Normal(x, 0, 1)))
